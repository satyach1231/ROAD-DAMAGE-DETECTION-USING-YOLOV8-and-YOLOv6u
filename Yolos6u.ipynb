# %% [markdown]
# # Importing the Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch

# Check if a GPU is available
if torch.cuda.is_available():
    print("GPU is available.")
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available.")
# Out:
# GPU is available.
# Device Name: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
print(torch.version.cuda)
# Out:
# 12.1

# %%
import torch
from IPython.display import Image
import shutil
import os
from random import choice

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
ML_Model = []
precision = []
recall = []
mAP = []

#function to call for storing the results
def storeResults(model, a,b,c):
    ML_Model.append(model)
    precision.append(round(a, 3))
    recall.append(round(b, 3))
    mAP.append(round(c, 3))

# %% [markdown]
# # **YoloV5s6u**

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov5s6u.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data=r"C:/Users/Deepak/Desktop/Road Damage Detection using Yolov8 - Copy/yolov5/data.yaml", epochs=10, imgsz=416)  # train the
# Out:
# New https://pypi.org/project/ultralytics/8.3.33 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6  Python-3.10.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
x = Image(filename='runs/detect/train37/F1_curve.png')
y = Image(filename='runs/detect/train37/PR_curve.png')
z = Image(filename='runs/detect/train37/confusion_matrix.png')
display(x, y,z)
